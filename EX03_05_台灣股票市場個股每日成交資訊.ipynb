2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.0.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘taipei_sans_tc_beta.ttf’
#
# taipei_sans_tc_beta 100%[===================>]  19.70M  71.8MB/s    in 0.3s
#
# 2025-04-29 06:31:54 (71.8 MB/s) - ‘taipei_sans_tc_beta.ttf’ saved [20659344/20659344]

# %%
import pandas as pd

def get_stock_data(date, stock_no):
  url = f'https://www.twse.com.tw/rwd/zh/afterTrading/STOCK_DAY?date={date}&stockNo={stock_no}&response=html'
  df_mth = pd.read_html(url, header=1)[0]
  return df_mth

# %%
import matplotlib
import matplotlib.pyplot as plt
# 新增字體
matplotlib.font_manager.fontManager.addfont('taipei_sans_tc_beta.ttf')
# 設定中文字型及負號正確顯示
plt.rcParams['font.sans-serif'] = 'Taipei Sans Tc Beta'
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd

def get_stock_data(date, stock_no):
  url = f'https://www.twse.com.tw/rwd/zh/afterTrading/STOCK_DAY?date={date}&stockNo={stock_no}&response=html'
  df = pd.read_html(url, header=1)[0]
  return df

'''
date_list = []
for i in range(3,16):
  year = 2024 + (i//12)
  mnth = i%12 + 1
  date_list.append(f'{year}{mnth:02}01')
'''

date_range = pd.date_range(start='20240401', end='2024-12-01', freq='MS')
date_list = date_range.strftime('%Y%m%d').to_list()

df = pd.DataFrame()
for date in date_list:
  df = pd.concat([df, get_stock_data(date, '0050')], ignore_index=True)

df
# Out:
#             日期     成交股數        成交金額     開盤價     最高價     最低價     收盤價  漲跌價差  \
# 0    113/04/01  5727780   904051439  158.20  158.75  157.25  157.40  -0.5
# 1    113/04/02  7924481  1261718566  158.45  159.65  158.40  159.65  2.25
# 2    113/04/03  5042947   799119313  158.65  158.90  157.80  158.55  -1.1
# 3    113/04/08  6124837   976164820  158.65  159.85  158.55  159.45   0.9
# 4    113/04/09  9043462  1465418271  160.00  163.35  159.90  163.25   3.8
# ..         ...      ...         ...     ...     ...     ...     ...   ...
# 181  113/12/25  6345182  1256839477  198.50  198.50  197.45  198.40   0.6
# 182  113/12/26  5000930   991798012  198.40  198.50  198.00  198.25 -0.15
# 183  113/12/27  7419893  1473166055  197.60  199.05  197.30  198.90  0.65
# 184  113/12/30  8999312  1783577316  198.15  198.65  197.65  197.80  -1.1
# 185  113/12/31  8290222  1625749078  196.70  196.90  195.60  195.75 -2.05
#
#       成交筆數
# 0     9814
# 1    11341
# 2    10098
# 3    12306
# 4    15355
# ..     ...
# 181  11290
# 182   7692
# 183  10934
# 184  11214
# 185  11738
#
# [186 rows x 9 columns]

# %%
df.plot(kind='line', x='日期', y='收盤價', figsize=(12, 4))
plt.show()

# %%
df.plot(kind='bar', x='日期', y='成交股數', figsize=(12, 4))
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,4))

df.plot(kind='line', x='日期', y='收盤價', ax=ax1, color='blue')

ax2 = ax1.twinx()
df.plot(kind='bar', x='日期', y='成交股數', ax=ax2, color='red')

plt.show()

# %%
df['漲跌價差'] = pd.to_numeric(df['漲跌價差'], errors='coerce')
df['Color'] = df['漲跌價差'].apply(lambda x: 'green' if x < 0 else 'red')

fig, ax1 = plt.subplots(figsize=(12,4))
df.plot(kind='line', x='日期', y='收盤價', ax=ax1, color='blue')
ax2 = ax1.twinx()
df.plot(kind='bar', x='日期', y='成交股數', ax=ax2, color=df['Color'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
